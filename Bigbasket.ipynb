# %%
# Importing Libraries
import numpy as np # for Linear Algebra
import pandas as pd # for Data Processing
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

a = pd.read_csv(r'C:\Users\User\Desktop\Kaggle Chalenges\Bigbasket\BigBasket Products.csv') #Uploading CSV or Excel File

#Display Headers
print("Head:", a.head())

#Display Information
print("Information:", a.info())

#Display describe
print("Describe:", a.describe())
# Out:
# Head:    index                                            product  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg
# 1      2                              Water Bottle - Orange
# 2      3                     Brass Angle Deep - Plain, No.2
# 3      4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      5                 Creme Soft Soap - For Hands & Body
#
#                  category           sub_category              brand  \
# 0        Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 1  Kitchen, Garden & Pets  Storage & Accessories         Mastercook
# 2    Cleaning & Household            Pooja Needs                Trm
# 3    Cleaning & Household   Bins & Bathroom Ware             Nakoda
# 4        Beauty & Hygiene       Bath & Hand Wash              Nivea
#
#    sale_price  market_price                      type  rating  \
# 0       220.0         220.0          Hair Oil & Serum     4.1
# ...

# %%
a = pd.read_csv('C:\Users\User\Desktop\Kaggle Chalenges\Bigbasket\BigBasket Products.csv', usecols = ["category", "sub_category", "product", "rating"])
a.head(12)
# Out:
#   Cell In[11], line 1
#     a = pd.read_csv('C:\Users\User\Desktop\Kaggle Chalenges\Bigbasket\BigBasket Products.csv', usecols = ["category", "sub_category", "product", "rating"])
#                                                                                              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
a = pd.read_csv('C:\\Users\\User\\Desktop\\Kaggle Chalenges\\Bigbasket\\BigBasket Products.csv', usecols = ["category", "sub_category", "product", "rating"])
a.head(12)
# Out:
#                                               product                category  \
# 0              Garlic Oil - Vegetarian Capsule 500 mg        Beauty & Hygiene
# 1                               Water Bottle - Orange  Kitchen, Garden & Pets
# 2                      Brass Angle Deep - Plain, No.2    Cleaning & Household
# 3   Cereal Flip Lid Container/Storage Jar - Assort...    Cleaning & Household
# 4                  Creme Soft Soap - For Hands & Body        Beauty & Hygiene
# 5                   Germ - Removal Multipurpose Wipes    Cleaning & Household
# 6                                        Multani Mati        Beauty & Hygiene
# 7                   Hand Sanitizer - 70% Alcohol Base        Beauty & Hygiene
# 8   Biotin & Collagen Volumizing Hair Shampoo + Bi...        Beauty & Hygiene
# 9                Scrub Pad - Anti- Bacterial, Regular    Cleaning & Household
# 10                           Wheat Grass Powder - Raw    Gourmet & World Food
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product       27554 non-null  object
#  1   category      27555 non-null  object
#  2   sub_category  27555 non-null  object
#  3   rating        18929 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 861.2+ KB

# %%
a.set_index("category")
# Out:
#                                                                   product  \
# category
# Beauty & Hygiene                   Garlic Oil - Vegetarian Capsule 500 mg
# Kitchen, Garden & Pets                              Water Bottle - Orange
# Cleaning & Household                       Brass Angle Deep - Plain, No.2
# Cleaning & Household    Cereal Flip Lid Container/Storage Jar - Assort...
# Beauty & Hygiene                       Creme Soft Soap - For Hands & Body
# ...                                                                   ...
# Beauty & Hygiene               Wottagirl! Perfume Spray - Heaven, Classic
# Gourmet & World Food                                             Rosemary
# Gourmet & World Food                         Peri-Peri Sweet Potato Chips
# Beverages                                       Green Tea - Pure Original
# Beauty & Hygiene                           United Dreams Go Far Deodorant
#
#                                     sub_category  rating
# category
# ...

# %%
a.set_index(["category", "sub_category"])
# Out:
#                                                                                            product  \
# category               sub_category
# Beauty & Hygiene       Hair Care                            Garlic Oil - Vegetarian Capsule 500 mg
# Kitchen, Garden & Pets Storage & Accessories                                 Water Bottle - Orange
# Cleaning & Household   Pooja Needs                                  Brass Angle Deep - Plain, No.2
#                        Bins & Bathroom Ware      Cereal Flip Lid Container/Storage Jar - Assort...
# Beauty & Hygiene       Bath & Hand Wash                         Creme Soft Soap - For Hands & Body
# ...                                                                                            ...
#                        Fragrances & Deos                Wottagirl! Perfume Spray - Heaven, Classic
# Gourmet & World Food   Cooking & Baking Needs                                             Rosemary
# ...
